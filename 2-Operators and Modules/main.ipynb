# %% [markdown]
# ## Practice Questions

# %% [markdown]
# - **Write a Python program to print “Python is Fun!” using a single print() statement.**

# %%
print("Operators and modules")
print("Project 2")
print("Project 2")
print("Project 2")
print("Project 2")
print("Project 2")
print("Project 2")
print("Project 2")
print("Project 2")
print("Project 2")
print("Project 2")
print("Project 2")
print("Project 2")
print("Project 2")
print("Project 2")
print("Project 2")
print("Project 2")
print("Project 2")
print("Project 2")
# Out:
# Operators and modules
# Project 2
# Project 2
# Project 2
# Project 2
# Project 2
# Project 2
# Project 2
# Project 2
# Project 2
# Project 2
# Project 2
# Project 2
# Project 2
# Project 2
# Project 2
# Project 2
# Project 2
# Project 2

# %% [markdown]
# - **Print your name and age in a single line output.**

# %%
print("My name is Aqib Ilyas and my age is **")
# Out:
# My name is Aqib Ilyas and my age is **

# %% [markdown]
# - **Print the numbers 1, 2, 3, 4 separated by a Hash(#) using the sep parameter.**

# %%
print("1", "2", "3", "4", sep="#")
# Out:
# 1#2#3#4

# %% [markdown]
# - **Use the end parameter to print "Hello" and "World" on the same line with a space in
# between.**

# %%
print("Hello", end= " ")
print("World")
# Out:
# Hello World

# %% [markdown]
# - **Print “Learning-Python-is-easy!” using sep and end parameters.**

# %%
print("Learning","Python","is","easy!", sep="-")
print("Learning", end="-")
print("Python", end="-")
print("is", end="-")
print("easy!")
# Out:
# Learning-Python-is-easy!
# Learning-Python-is-easy!

# %% [markdown]
# - **Print the numbers 10, 20, 30 separated by a comma and a space (", "), and ensure the next
# print statement starts on the same line.**

# %%
print("10", "20", "30", sep=", ")
# Out:
# 10, 20, 30

# %% [markdown]
# - **Write a program that prints your name, age and city on the same line, each separated by
# the word "and".**

# %%
print("Aqib Ilyas", "age is **", "belongs to Karachi,Pakistan", sep=" and ")
# Out:
# Aqib Ilyas and age is ** and belongs to Karachi,Pakistan

# %% [markdown]
# - **Use the print() function to output the following without using multiple print statements:<br>
# Welcome to Python.<br>
# Let's learn together.**

# %%
print("Welcome to Python", "Let's learn together", sep="\n")
# Out:
# Welcome to Python
# Let's learn together

# %% [markdown]
# - **What will be the output of the following code:<br>
#        a = 5<br>
#        a = 2.5<br>
#        print(a)<br>
#        print(type(a))**

# %%
a=5
a=2.5
print(a)
print(type(a))
# Out:
# 2.5
# <class 'float'>

# %% [markdown]
# - **What will be the output of the following code:<br>
#       value = "False"<br>
#       print(type(value))**

# %%
value = "False"
print(type(value))
# Out:
# <class 'str'>

# %% [markdown]
# - **What will be the data type of the value returned by input() and output of the following code?<br>
#       age = input("Enter your age: ")<br>
#       print(age + 5)**

# %%
age = int(input("Enter your age: "))
print(age + 5)
print(type(age))
# Out:
# 11
# <class 'int'>

# %% [markdown]
# - **Write Code:<br>
#       Ask the user to enter two numbers.<br>
#       Swap those and print**

# %%
a = int(input("Enter number 1: "))
b = int(input("Enter number 2: "))
a,b = b,a
print("Now the value of a is: ", a)
print("Now the value of b is: ", b)
# Out:
# Now the value of a is:  9
# Now the value of b is:  5

# %% [markdown]
# - **Create variables name and city with your name and city as values. Print both variables in a single line.**

# %%
name = "Aqib Ilyas"; city = "Karachi"
print(f"My name is {name} and my city is {city}")
# Out:
# My name is Aqib Ilyas and my city is Karachi

# %% [markdown]
# - **Start with x = 5. Reassign x to 10. Print the final value of x.**

# %%
x=5
x=10
print(x)
# Out:
# 10

# %% [markdown]
# - **Which of these variable names are valid in Python: my_var, 123_var, myVar1, your var? Use all these variables and show output**

# %%
my_var = "my_var is vaid"
123_var = "Invalid"
myVar1 = "myVar1 is valid"
your var = "Invald"
# Out:
#   Cell In[4], line 2
#     123_var = "Invalid"
#        ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# - **Swap two variables a = 10 and b = 5 without using a third variable**

# %%
a = 10
b = 5
a,b = b,a   #Swaped the value 
print(f"Value of a is {a} and value of b is {b}")
# Out:
# Value of a is 5 and value of b is 10

# %% [markdown]
# - **Concatenate strings stored in two different variables first_name and second_name and print result.**

# %%
first_name = "Aqib"
second_name = "Ilyas"
print("My full name is:" , first_name + " " + second_name)
# Out:
# My full name is: Aqib Ilyas

# %% [markdown]
# - **Use f-strings to print your bio and input function must be used.**

# %%
user_input = input("Enter bio")
print(f"My short bio is: {user_input}")
# Out:
# My short bio is: This is Aqib Ilyas

# %% [markdown]
# - **Ask the user for their name, age, and city, then print a formatted sentence using format method.**

# %%
user_name = input("Enter your name")
user_age = int(input("Enter your age"))
user_city = input("Enter your city")
print(f"My name is {user_name}, I belong to {user_city} and my age is {user_age}")
# Out:
# My name is AI, I belong to Karachi and my age is 4

# %% [markdown]
# - **Take input from user as product & cost then print output in following manner: The Laptop costs $1200.**

# %%
user_product = input("Your prouct name is")
product_cost = int(input("Enter the product amount"))
print(f"The {user_product} costs ${product_cost}.")
# Out:
# The Tablet costs $300.

# %% [markdown]
# - **Print the names of five programming languages separated by (->):<br>
#         Using single print statement<br>
#         Using multiple print statement**

# %%
print("C", "C++", "C#", "Python", "Java", sep=" -> ")
print("C", end=" -> ")
print("C++", end=" -> ")
print("C#", end=" -> ")
print("Python", end=" -> ")
print("Java")
# Out:
# C -> C++ -> C# -> Python -> Java
# C -> C++ -> C# -> Python -> Java

# %% [markdown]
# - **Ask the user to input product and its price then generate a receipt using f-string.**

# %%
print("--------Receipt---------")
print(f"{user_product}         ${product_cost}")
print("------------------------")
print(f"Total:         ${product_cost}")
# Out:
# --------Receipt---------
# Tablet         $300
# ------------------------
# Total:         $300
