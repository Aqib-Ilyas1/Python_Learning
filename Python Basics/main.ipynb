# %% [markdown]
# - **Write a Python program to print “Python is Fun!” using a single print() statement.**

# %%
print("Pyhton is Fun!")
# Out:
# Pyhton is Fun!

# %% [markdown]
# - **Print your name and age in a single line output.**

# %%
print("My name is Aqib Ilyas and my age is **")
# Out:
# My name is Aqib Ilyas and my age is **

# %% [markdown]
# - **Print the numbers 1, 2, 3, 4 separated by a Hash(#) using the sep parameter.**

# %%
print("1", "2", "3", "4", sep="#")
# Out:
# 1#2#3#4

# %% [markdown]
# - **Use the end parameter to print "Hello" and "World" on the same line with a space in
# between.**

# %%
print("Hello", end= " ")
print("World")
# Out:
# Hello World

# %% [markdown]
# - **Print “Learning-Python-is-easy!” using sep and end parameters.**

# %%
print("Learning","Python","is","easy!", sep="-")
print("Learning", end="-")
print("Python", end="-")
print("is", end="-")
print("easy!")
# Out:
# Learning-Python-is-easy!
# Learning-Python-is-easy!

# %% [markdown]
# - **Print the numbers 10, 20, 30 separated by a comma and a space (", "), and ensure the next
# print statement starts on the same line.**

# %%
print("10", "20", "30", sep=", ")
# Out:
# 10, 20, 30

# %% [markdown]
# - **Write a program that prints your name, age and city on the same line, each separated by
# the word "and".**

# %%
print("Aqib Ilyas", "age is **", "belongs to Karachi,Pakistan", sep=" and ")
# Out:
# Aqib Ilyas and age is ** and belongs to Karachi,Pakistan

# %% [markdown]
# - **Use the print() function to output the following without using multiple print statements:<br>
# Welcome to Python.<br>
# Let's learn together.**

# %%
print("Welcome to Python", "Let's learn together", sep="\n")
# Out:
# Welcome to Python
# Let's learn together

# %% [markdown]
# - **What will be the output of the following code:<br>
#        a = 5<br>
#        a = 2.5<br>
#        print(a)<br>
#        print(type(a))**

# %%
a=5
a=2.5
print(a)
print(type(a))
# Out:
# 2.5
# <class 'float'>

# %% [markdown]
# - **What will be the output of the following code:<br>
#       value = "False"<br>
#       print(type(value))**

# %%
value = "False"
print(type(value))
# Out:
# <class 'str'>

# %% [markdown]
# - **What will be the data type of the value returned by input() and output of the following code?<br>
#       age = input("Enter your age: ")<br>
#       print(age + 5)**

# %%
age = int(input("Enter your age: "))
print(age + 5)
print(type(age))
# Out:
# 11
# <class 'int'>

# %% [markdown]
# - **Write Code:<br>
#       Ask the user to enter two numbers.<br>
#       Swap those and print**

# %%
a = int(input("Enter number 1: "))
b = int(input("Enter number 2: "))
a,b = b,a
print("Now the value of a is: ", a)
print("Now the value of b is: ", b)
# Out:
# Now the value of a is:  9
# Now the value of b is:  5
